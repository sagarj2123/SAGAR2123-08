# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarj2123/SAGAR2123-08/blob/main/SAGAR_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Input

# %%
model_vgg16 = VGG16(weights='imagenet')
model_vgg16.summary()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model_vgg19 = VGG19(weights='imagenet')
model_vgg19.summary()
# Out:
# ...
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
def AlexNet():
    model = tf.keras.Sequential([
        Conv2D(96, (11,11), strides=4, activation='relu', input_shape=(227,227,3)),
        MaxPooling2D(pool_size=(3,3), strides=2),

        Conv2D(256, (5,5), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(3,3), strides=2),

        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(256, (3,3), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(3,3), strides=2),

        Flatten(),
        Dense(4096, activation='relu'),
        Dense(4096, activation='relu'),
        Dense(1000, activation='softmax')
    ])
    return model

alexnet_model = AlexNet()
alexnet_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 55, 55, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 27, 27, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from tensorflow.keras.applications import InceptionV3

model_google = InceptionV3(weights='imagenet')
model_google.summary()
# Out:
# ...
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "inception_v3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 149, 149,  │        864 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 149, 149,  │         96 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ...

# %%
import tensorflow as tf

# Prebuilt models
from tensorflow.keras.applications import VGG16, VGG19, InceptionV3

# Layers for custom model (AlexNet)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
vgg16_model = VGG16(weights='imagenet')

# %%
vgg19_model = VGG19(weights='imagenet')

# %%
googlenet_model = InceptionV3(weights='imagenet')

# %%
def AlexNet():
    model = Sequential([
        Conv2D(96, (11,11), strides=4, activation='relu', input_shape=(227,227,3)),
        MaxPooling2D((3,3), strides=2),

        Conv2D(256, (5,5), padding='same', activation='relu'),
        MaxPooling2D((3,3), strides=2),

        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(256, (3,3), padding='same', activation='relu'),
        MaxPooling2D((3,3), strides=2),

        Flatten(),
        Dense(4096, activation='relu'),
        Dense(4096, activation='relu'),
        Dense(1000, activation='softmax')
    ])
    return model

alexnet_model = AlexNet()

# %%
print("VGG16")
vgg16_model.summary()

print("\nVGG19")
vgg19_model.summary()

print("\nGoogLeNet (InceptionV3)")
googlenet_model.summary()

print("\nAlexNet")
alexnet_model.summary()
# Out:
# VGG16
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c955b619-20aa-4b1d-8980-1104f741b16b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c955b619-20aa-4b1d-8980-1104f741b16b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_file = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

# %%
import os
print(os.listdir('/content/dataset'))
# Out:
# ['animals']

# %%
import os

# Path to the 'animals' folder
animals_path = '/content/dataset/animals'

# List the folders inside 'animals' (should be cat and dog)
folders = os.listdir(animals_path)
print(folders)
# Out:
# ['cat', 'dog']

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, VGG19, InceptionV3  # GoogLeNet approx.
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Dataset path
dataset_path = '/content/dataset/animals'

# ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    preprocessing_function=lambda x: x/255.0,  # normalize pixels
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    classes=['cat', 'dog']
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    classes=['cat', 'dog']
)
# Out:
# Found 800 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
def build_model(base_model, num_classes=2):
    # Freeze base model
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))
vgg16_model = build_model(vgg16_base)
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
vgg19_base = VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))
vgg19_model = build_model(vgg19_base)
# Out:
# ...
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

def build_alexnet(input_shape=(224,224,3), num_classes=2):
    model = Sequential([
        Conv2D(96, (11,11), strides=4, activation='relu', input_shape=input_shape),
        BatchNormalization(),
        MaxPooling2D((3,3), strides=2),

        Conv2D(256, (5,5), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((3,3), strides=2),

        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(384, (3,3), padding='same', activation='relu'),
        Conv2D(256, (3,3), padding='same', activation='relu'),
        MaxPooling2D((3,3), strides=2),

        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=Adam(0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

alexnet_model = build_alexnet()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.applications import InceptionV3

inception_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(224,224,3))
googlenet_model = build_model(inception_base)
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
import matplotlib.pyplot as plt

# Dictionary to store training history
histories = {}

# List of models
models = {
    'VGG16': vgg16_model,
    'VGG19': vgg19_model,
    'AlexNet': alexnet_model,
    'GoogLeNet': googlenet_model
}

epochs = 10  # adjust if needed

# Train each model and save history
for name, model in models.items():
    print(f"=== Training {name} ===")
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        verbose=1
    )
    histories[name] = history

# ==========================
# Plot accuracy curves
# ==========================
plt.figure(figsize=(12,6))

for name, history in histories.items():
    plt.plot(history.history['accuracy'], label=f'{name} Train Acc')
    plt.plot(history.history['val_accuracy'], '--', label=f'{name} Val Acc')

plt.title('Model Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# ==========================
# Plot loss curves
# ==========================
plt.figure(figsize=(12,6))

for name, history in histories.items():
    plt.plot(history.history['loss'], label=f'{name} Train Loss')
    plt.plot(history.history['val_loss'], '--', label=f'{name} Val Loss')

plt.title('Model Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === Training VGG16 ===
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.9842 - loss: 0.0628
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16091/1059266820.py in <cell line: 0>()
#      17 for name, model in models.items():
#      18     print(f"=== Training {name} ===")
# ---> 19     history = model.fit(
#      20         train_data,
#      21         validation_data=val_data,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Set epochs to 5
epochs = 5

# Optional: Early stopping to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True
)

# Dictionary to store training history
histories = {}

# List of models
models = {
    'VGG16': vgg16_model,
    'VGG19': vgg19_model,
    'AlexNet': alexnet_model,
    'GoogLeNet': googlenet_model
}

# Train all models with 5 epochs
for name, model in models.items():
    print(f"=== Training {name} for {epochs} epochs ===")
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        verbose=1,
        callbacks=[early_stop]
    )
    histories[name] = history

# ==========================
# Plot accuracy curves
# ==========================
plt.figure(figsize=(12,6))
for name, history in histories.items():
    plt.plot(history.history['accuracy'], label=f'{name} Train Acc')
    plt.plot(history.history['val_accuracy'], '--', label=f'{name} Val Acc')

plt.title('Model Accuracy Comparison (5 Epochs)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# ==========================
# Plot loss curves
# ==========================
plt.figure(figsize=(12,6))
for name, history in histories.items():
    plt.plot(history.history['loss'], label=f'{name} Train Loss')
    plt.plot(history.history['val_loss'], '--', label=f'{name} Val Loss')

plt.title('Model Loss Comparison (5 Epochs)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# === Training VGG16 for 5 epochs ===
# Epoch 1/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 566s 23s/step - accuracy: 0.9900 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 533s 21s/step - accuracy: 0.9987 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 3/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 527s 21s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 4/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 527s 21s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 5/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 528s 21s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0040
# === Training VGG19 for 5 epochs ===
# Epoch 1/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 669s 27s/step - accuracy: 0.9112 - loss: 0.2154 - val_accuracy: 0.9950 - val_loss: 0.0348
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 657s 27s/step - accuracy: 0.9912 - loss: 0.0278 - val_accuracy: 0.9950 - val_loss: 0.0130
# ...

# %%
for name, history in histories.items():
    # Accuracy
    plt.figure()
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title(f'{name} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Loss
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{name} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Example: rebuild VGG16 model if not in memory
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

def build_model(base_model, num_classes=2):
    for layer in base_model.layers:
        layer.trainable = False
    x = Flatten()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer=Adam(0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

vgg16_model = build_model(vgg16_base)
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Example: for VGG16 model
y_pred_probs = model.predict(validation_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12098/2342409495.py in <cell line: 0>()
#       1 # Example: for VGG16 model
# ----> 2 y_pred_probs = model.predict(validation_generator)
#       3 y_pred = np.argmax(y_pred_probs, axis=1)
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

val_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = val_datagen.flow_from_directory(
    r"C:\Users\VIDYA SAGAR BADUGU\Downloads\archive",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False   # VERY IMPORTANT
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12098/717824752.py in <cell line: 0>()
#       3 val_datagen = ImageDataGenerator(rescale=1./255)
#       4
# ----> 5 validation_generator = val_datagen.flow_from_directory(
#       6     r"C:\Users\VIDYA SAGAR BADUGU\Downloads\archive",
#       7     target_size=(224, 224),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1134         keep_aspect_ratio=False,
#    1135     ):
# -> 1136         return DirectoryIterator(
#    1137             directory,
#    1138             self,
#
# ...

# %%
import os

print(os.path.exists(r"C:\Users\VIDYA SAGAR BADUGU\Downloads\archive"))
# Out:
# False

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17c41a5e-6aad-4ba9-a765-60630936164f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17c41a5e-6aad-4ba9-a765-60630936164f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/archive')

# %%
import os

for root, dirs, files in os.walk('/content/archive'):
    print("ROOT:", root)
    print("DIRS:", dirs)
    break
# Out:
# ROOT: /content/archive
# DIRS: ['animals']

# %%
for root, dirs, files in os.walk('/content/archive/archive'):
    print(root, dirs)
    break

# %%
import os

for root, dirs, files in os.walk('/content'):
    print("ROOT:", root)
    print("DIRS:", dirs)
    print("------")
# Out:
# ROOT: /content
# DIRS: ['.config', 'drive', 'archive', 'sample_data']
# ------
# ROOT: /content/.config
# DIRS: ['logs', 'configurations']
# ------
# ROOT: /content/.config/logs
# DIRS: ['2026.04.02']
# ------
# ROOT: /content/.config/logs/2026.04.02
# DIRS: []
# ------
# ROOT: /content/.config/configurations
# DIRS: []
# ------
# ROOT: /content/drive
# DIRS: ['MyDrive', 'Othercomputers', '.shortcut-targets-by-id', '.Trash-0', '.Encrypted']
# ------
# ROOT: /content/drive/MyDrive
# DIRS: ['Important', 'Colab Notebooks']
# ------
# ROOT: /content/drive/MyDrive/Important
# DIRS: []
# ------
# ROOT: /content/drive/MyDrive/Colab Notebooks
# DIRS: []
# ------
# ROOT: /content/drive/Othercomputers
# DIRS: ['USB and External Devices']
# ------
# ROOT: /content/drive/Othercomputers/USB and External Devices
# DIRS: ['iQOO Z3 5G', 'Bhanu A6+']
# ------
# ROOT: /content/drive/Othercomputers/USB and External Devices/iQOO Z3 5G
# DIRS: []
# ------
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

val_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = val_datagen.flow_from_directory(
    '/content/archive/animals',   # ✅ CORRECT PATH
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1000 images belonging to 2 classes.

# %%
validation_generator.reset()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_probs = vgg16_model.predict(validation_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

y_true = validation_generator.classes

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("VGG16 Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

print(classification_report(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28844/1657231355.py in <cell line: 0>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 y_pred_probs = vgg16_model.predict(validation_generator)
#       7 y_pred = np.argmax(y_pred_probs, axis=1)
#       8
#
# NameError: name 'vgg16_model' is not defined

# %%
vgg16_model.save('vgg16_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28844/1495651030.py in <cell line: 0>()
# ----> 1 vgg16_model.save('vgg16_model.h5')
#
# NameError: name 'vgg16_model' is not defined

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

# %%
vgg16_model = Sequential()
vgg16_model.add(base_model)
vgg16_model.add(Flatten())
vgg16_model.add(Dense(128, activation='relu'))
vgg16_model.add(Dense(2, activation='softmax'))  # 2 classes: cat & dog

# %%
vgg16_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, GlobalAveragePooling2D
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report

# %%
datagen = ImageDataGenerator(rescale=1./255)

validation_generator = datagen.flow_from_directory(
    '/content/archive/animals',   # ✅ your correct path
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

num_classes = validation_generator.num_classes
# Out:
# Found 1000 images belonging to 2 classes.

# %%
base_vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

x = base_vgg16.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)

vgg16_model = Model(inputs=base_vgg16.input, outputs=output)

vgg16_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

vgg16_model.fit(validation_generator, epochs=3)
# Out:
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1447s 45s/step - accuracy: 0.5250 - loss: 130763.1250
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1378s 43s/step - accuracy: 0.4480 - loss: 0.7534
# Epoch 3/3
# 20/32 ━━━━━━━━━━━━━━━━━━━━ 8:12 41s/step - accuracy: 0.5919 - loss: 0.7245

# %%
base_vgg19 = VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))

x = base_vgg19.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)

vgg19_model = Model(inputs=base_vgg19.input, outputs=output)

vgg19_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

vgg19_model.fit(validation_generator, epochs=3)

# %%
alexnet_model = Sequential()

alexnet_model.add(Conv2D(96, (11,11), strides=4, activation='relu', input_shape=(224,224,3)))
alexnet_model.add(MaxPooling2D(3, strides=2))

alexnet_model.add(Conv2D(256, (5,5), padding='same', activation='relu'))
alexnet_model.add(MaxPooling2D(3, strides=2))

alexnet_model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
alexnet_model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
alexnet_model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
alexnet_model.add(MaxPooling2D(3, strides=2))

alexnet_model.add(Flatten())
alexnet_model.add(Dense(4096, activation='relu'))
alexnet_model.add(Dropout(0.5))
alexnet_model.add(Dense(4096, activation='relu'))
alexnet_model.add(Dropout(0.5))
alexnet_model.add(Dense(num_classes, activation='softmax'))

alexnet_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

alexnet_model.fit(validation_generator, epochs=3)

# %%
input_layer = Input(shape=(224,224,3))

x = Conv2D(64, (7,7), strides=2, padding='same', activation='relu')(input_layer)
x = MaxPooling2D(3, strides=2)(x)

x = Conv2D(192, (3,3), padding='same', activation='relu')(x)
x = MaxPooling2D(3, strides=2)(x)

x = Conv2D(256, (3,3), padding='same', activation='relu')(x)
x = Conv2D(480, (3,3), padding='same', activation='relu')(x)
x = MaxPooling2D(3, strides=2)(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)

output = Dense(num_classes, activation='softmax')(x)

googlenet_model = Model(inputs=input_layer, outputs=output)

googlenet_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

googlenet_model.fit(validation_generator, epochs=3)
